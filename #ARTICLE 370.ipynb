# %% [markdown]
# # #(ARTICLE 370)

# %% [markdown]
# ### WHAT IS ARTICLE 370 ?

# %% [markdown]
# ->Article 370 of the Indian constitution gave special status to Jammu and Kashmir — a region located in the northern part of Indian subcontinent which was administered by India as a state from 1954 to 31 October 2019, and a part of the larger region of Kashmir, which has been the subject of dispute between India, Pakistan, and China since 1947 ->The deadly terror attack in Jammu & Kashmir's Pulwama on 14 February in which 40 CRPF personnel were martyred, demands for scrapping Article 370 of the Indian Constitution have intensified. ->Article 370 grants special status to Jammu & Kashmir and also limits the powers of the Parliament for making laws concerning the state. ->Article 370 of the Indian Constitution extends a provision by which Jammu & Kashmir enjoys special autonomous status. ->The residents of the state live under a separate set of laws, such as those relating to "citizenship, ownership of property, and fundamental rights". ->All the provisions of the Constitution that apply to other Indian states are not applicable to the northern state. ->Previously The architect of the Constitution, Dr. BR Ambedkar, had refused to draft Article 370. The then PM Jawaharlal Nehru, in 1949, asked Kashmiri leader Sheikh Abdullah to draft it. However, Gopalaswami Ayyangar, a Union Minister and former Diwan to J&K's Maharajah Hari Singh, eventfully drafted Article 370. ->According to the article, except for laws related to defense, foreign affairs, finance, and communications, the Parliament requires the J&K state government's agreement for applying all the other laws in the state. ->J&K laws concerning citizenship, fundamental rights, and property ownership. ->The residents of other Indian states cannot purchase land or other property in J&Kthe Union government doesn't have the power to declare a financial emergency in J&K as per Article 360.

# %% [markdown]
# ### WHERE DO WE GET THE DATA ?

# %% [markdown]
# -> We took the data from the twitter.
# -> We consider all the inputs of public
# -> It helps to analyze the sentiment of the topic
# -> To check in what way the public responds for the incidents happenening around
# -> It helps to know the opinions of the people also

# %% [markdown]
# ### HOW DID I SCRAP THE DATA ?

# %% [markdown]
# -> I scrapped the data from twitter -> Search the interested topic in the twitter search -> Click on advance search and fill the details as per needed like exact words, hashtag’s, language, date of event occurring and end date -> Copy the URL appeared on the search bar -> Install all libraries of tweet scrapper -> Open anaconda prompt -> In anaconda prompt install "pip install -r requirements" -> In anaconda prompt "scrapy crawl TweetScrapper -a query="give the saved URL from twitter" -> It will scrap all the tweets along with the pages -> all the scrapped pages directly stored in TweetScrapper - data folder -> Data folder will get two files -> one is -> data( it consists of files for each of the tweet),other is ->tweets(empty file) -> we will execute a code for converting all the files into a CSV file-> -> the file will automatically get saved in TweetScrapper -> the dataset is now ready for execution

# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'C:\\Users\\Administrator\\Desktop\\TweetScraper-master'

# %%
# %cd C:\Users\Administrator\Desktop\TweetScraper-master
# Out:
# C:\Users\Administrator\Desktop\TweetScraper-master

# %% [markdown]
# ### IMPORTING THE DATASET

# %%
df=pd.read_csv('Tweets.csv',sep=",")# READING THE CSV FILE FROM THE DATA
df.head()# CHECKING THE FIRST 10 OF THE VARIABLES DATA
# Out:
#                     ID             datetime has_media  is_reply  is_retweet  \
# 0  1158166245864116224  2019-08-04 17:02:05       NaN     False       False
# 1  1158167278761979904  2019-08-04 17:06:11       NaN      True       False
# 2  1158167573445271552  2019-08-04 17:07:21       NaN      True       False
# 3  1158170808117628928  2019-08-04 17:20:13       NaN     False       False
# 4  1158172093902512128  2019-08-04 17:25:19       NaN     False       False
#
#   medias  nbr_favorite  nbr_reply  nbr_retweet  \
# 0    NaN             1          0            0
# 1    NaN             0          0            0
# 2    NaN             0          0            0
# 3    NaN             1          0            0
# 4    NaN             0          0            1
#
#                                                 text  \
# 0  The #Article370  & #Article35A  are against th...
# 1  After Phulwama Gafoor said in his talk Media d...
# 2  y r u instigating people... stop spreading ven...
# ...

# %%
tweets=df # STORING THE DATA SET INTO TWEETS
tweets.info() #INFORMATION OF ALL THE DATASET
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88333 entries, 0 to 88332
# Data columns (total 13 columns):
# ID               88333 non-null int64
# datetime         88333 non-null object
# has_media        8457 non-null object
# is_reply         88333 non-null bool
# is_retweet       88333 non-null bool
# medias           8457 non-null object
# nbr_favorite     88333 non-null int64
# nbr_reply        88333 non-null int64
# nbr_retweet      88333 non-null int64
# text             88333 non-null object
# url              88333 non-null object
# user_id          88333 non-null int64
# usernameTweet    88333 non-null object
# dtypes: bool(2), int64(5), object(6)
# memory usage: 7.6+ MB

# %%
tweets.shape # NO OF ROWS AND COLUMNS
# Out:
# (88333, 13)

# %%
tweets.isnull().sum() # CHECKING THE MISSING VALUES OF EACH COLUMNS
# Out:
# ID                   0
# datetime             0
# has_media        79876
# is_reply             0
# is_retweet           0
# medias           79876
# nbr_favorite         0
# nbr_reply            0
# nbr_retweet          0
# text                 0
# url                  0
# user_id              0
# usernameTweet        0
# dtype: int64

# %% [markdown]
# -> THERE ARE MISSING VALUES IN has_media AND medias

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
tweets['has_media'].value_counts() # KNOWING THE DIFFERENT TYPES OF DATA and its count IN HAS_MEDIA COLUMNS
# Out:
# True    8457
# Name: has_media, dtype: int64

# %%
tweets['medias'].value_counts() # KNOWING THE DIFFERENT TYPES OF DATA and its count IN MEDIA COLUMNS
# Out:
# []                             225
# ['https://t.co/29xt05PIWz']     88
# ['https://t.co/LMoVths5dP']     66
# ['https://t.co/zvZPyg1n5h']     24
# ['https://t.co/P3l82ftocV']     23
# ['https://t.co/H0sHAbAitt']     18
# ['https://t.co/80f0Lg0yLG']     16
# ['https://t.co/Z7OxXX1bie']     15
# ['https://t.co/yS8m6ijQvI']     13
# ['https://t.co/xeBTyQmFJX']     12
# ['https://t.co/3u2iY9XVMT']     12
# ['https://t.co/HZLw28ashC']     11
# ['https://t.co/k20q6A4EGK']     11
# ['https://t.co/2zJNbvDuga']     10
# ['https://t.co/W2RpDlP6qw']     10
# ['https://t.co/32mHj53gql']     10
# ['https://t.co/5MR6G29vQU']     10
# ['https://t.co/R2R3RpUPf7']      9
# ['https://t.co/7ypMUepUFG']      8
# ['https://t.co/31boTVTOc7']      8
# ['https://t.co/31boTVCdkz']      8
# ['https://t.co/t39exwYALd']      8
# ['https://t.co/JNXLR3pwyn']      8
# ['https://t.co/dCvBzrB0Mb']      7
# ['https://t.co/5MR6G2r7fu']      7
# ['https://t.co/RMTkBGOv2b']      7
# ['https://t.co/6aY9MJEutN']      6
# ...

# %%
tweets['is_reply'].value_counts() #KNOWING THE DIFFERENT TYPES OF DATA and its count IS REPLY COLUMNS
# Out:
# False    77907
# True     10426
# Name: is_reply, dtype: int64

# %%
tweets['is_retweet'].value_counts() # KNOWING THE DIFFERENT TYPES OF DATA and its count IS RETWEET COLUMNS
# Out:
# False    88333
# Name: is_retweet, dtype: int64

# %%
tweets['nbr_favorite'].describe() # defining the statictical values of  NBR_FAVORITE columns
# Out:
# count    88333.000000
# mean        32.282465
# std        494.136409
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max      67061.000000
# Name: nbr_favorite, dtype: float64

# %%
tweets['nbr_reply'].describe()# defining the statictical values of NBR_REPLY columns
# Out:
# count    88333.000000
# mean         2.020977
# std         51.084897
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      10161.000000
# Name: nbr_reply, dtype: float64

# %%
tweets['nbr_retweet'].describe() # defining the statictical values of NBR_RETWEET columns
# Out:
# count    88333.000000
# mean         6.961102
# std         90.080031
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max       7567.000000
# Name: nbr_retweet, dtype: float64

# %% [markdown]
# ### DROPPING THE UNECCESSARY COLUMNS

# %%
# THE UNNECESSARY COLUMNS IN THE DATA SET IS URL,ID NUMBER,MEDIAS,HAS_MEDIAS,USER_ID
tweets=tweets.drop(['medias','has_media','url','ID','user_id'],axis=1) # DROPPING THE COLUMNS
tweets.head()
# Out:
#               datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0  2019-08-04 17:02:05     False       False             1          0
# 1  2019-08-04 17:06:11      True       False             0          0
# 2  2019-08-04 17:07:21      True       False             0          0
# 3  2019-08-04 17:20:13     False       False             1          0
# 4  2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            0  The #Article370  & #Article35A  are against th...
# 1            0  After Phulwama Gafoor said in his talk Media d...
# 2            0  y r u instigating people... stop spreading ven...
# 3            0  After observing #bjp  govt in last 5 years, I ...
# 4            1  Always a good thing to listen AGAIN to people ...
#
#      usernameTweet
# 0         NeeloyWB
# 1          raj_ubl
# 2       123ashwini
# 3         NeeloyWB
# 4  league_of_india

# %% [markdown]
# ### ALL THE COLUMN NAMES IN DATASET

# %%
tweets.columns # NAMES OF THE PRESENT COLUMNS
# Out:
# Index(['datetime', 'is_reply', 'is_retweet', 'nbr_favorite', 'nbr_reply',
#        'nbr_retweet', 'text', 'usernameTweet'],
#       dtype='object')

# %%
tweets.shape# AFTER DROP CHECKING THE ROWS AND COLUMNS
# Out:
# (88333, 8)

# %%
tweets.isnull().sum() # THERE IS NO MISIING VALUES IN THE GIVEN DATASET
# Out:
# datetime         0
# is_reply         0
# is_retweet       0
# nbr_favorite     0
# nbr_reply        0
# nbr_retweet      0
# text             0
# usernameTweet    0
# dtype: int64

# %%
tweets.groupby(['nbr_favorite', 'is_reply']).mean().describe()
# It is used to analyse the statistical values of 'nbr_favorite' & 'is_reply'
# Out:
#           nbr_reply  nbr_retweet
# count   1332.000000  1332.000000
# mean      86.488252   315.242444
# std      400.852202   650.122790
# min        0.000000     0.000000
# 25%        6.735577    38.593750
# 50%       16.000000   101.000000
# 75%       45.812500   270.500000
# max    10161.000000  7567.000000

# %%
tweets.groupby(['is_retweet', 'nbr_retweet']).mean().describe()
# It is used to analyse the statistical values of 'nbr_favorite' & 'is_reply' & 'is_retweet'
# Out:
#          is_reply  nbr_favorite     nbr_reply
# count  560.000000    560.000000    560.000000
# mean     0.014482   2915.393306    169.360056
# std      0.068646   5344.877976    599.873620
# min      0.000000      0.997482      0.142045
# 25%      0.000000    549.105556     17.000000
# 50%      0.000000   1308.000000     40.142857
# 75%      0.000000   2932.750000    103.500000
# max      1.000000  67061.000000  10161.000000

# %%
import matplotlib.pyplot as plt
df = pd.DataFrame(tweets, columns = ['nbr_favorite','nbr_reply','nbr_retweet'] ) # histogram for numerical data.
  
# create histogram for numeric data 
df.hist() 
  
# show plot 
plt.show()

# %%
df.plot.box() 
  
# individual attribute box plot 
plt.boxplot(df['nbr_favorite']) 
plt.show()

# %%
df.plot.box() 
  
# individual attribute box plot 
plt.boxplot(df['nbr_reply']) 
plt.show()

# %%
df.plot.box() 
  
# individual attribute box plot 
plt.boxplot(df['nbr_retweet']) 
plt.show()

# %% [markdown]
# -> From all the graphs the nbr_favourites has "outliers" and the nbr_reply and nbr_tweets has "outliers"

# %% [markdown]
# ## Length of Tweets

# %%
len(tweets) # TOTAL NUMBER OF TWEETS
# Out:
# 88333

# %%
 # PASSING ALL THE TEXT TO FING THE LENGTH BY GIVING APPLY FUNCTION
tweets['len_text']=tweets['text'].apply(lambda x:len(x.split()))
tweets.head(5) # STORING THE LENGTH OF TEXT IN A NEW COLUMN
# Out:
#               datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0  2019-08-04 17:02:05     False       False             1          0
# 1  2019-08-04 17:06:11      True       False             0          0
# 2  2019-08-04 17:07:21      True       False             0          0
# 3  2019-08-04 17:20:13     False       False             1          0
# 4  2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            0  The #Article370  & #Article35A  are against th...
# 1            0  After Phulwama Gafoor said in his talk Media d...
# 2            0  y r u instigating people... stop spreading ven...
# 3            0  After observing #bjp  govt in last 5 years, I ...
# 4            1  Always a good thing to listen AGAIN to people ...
#
#      usernameTweet  len_text
# 0         NeeloyWB        27
# 1          raj_ubl        37
# 2       123ashwini        17
# ...

# %%
tweets['len_text'].describe()
# Out:
# count    88333.000000
# mean        25.138080
# std         12.427031
# min          1.000000
# 25%         15.000000
# 50%         24.000000
# 75%         35.000000
# max         67.000000
# Name: len_text, dtype: float64

# %% [markdown]
# ### IMPORT THE LIBRARIES

# %%
# LIBRARIES
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.kdeplot(tweets['len_text']).set_title(" Distribution of Length of Text") #GRAPH FOR LENGTH OF THE TWEETS
# Out:
# Text(0.5, 1.0, ' Distribution of Length of Text')

# %% [markdown]
# ## NUMBER OF RETWEETS

# %%
tweets['is_retweet'] = tweets['text'].apply(lambda x: x[:2]=='RT')
tweets['is_retweet'].head()# number of retweets
tweets['is_retweet'].value_counts()
# Out:
# False    88207
# True       126
# Name: is_retweet, dtype: int64

# %% [markdown]
#  ##### FROM THE ABOVE DATA IT IS CLEAR THAT
#     #-> THE 126 PEOPLE TWEETED THIER OPINION AGAIN ON THE SAME ISSUE
#     #->THE 88207 PEOPLE TWEETED ONLY ONCE

# %%
sns.kdeplot(tweets['is_retweet']).set_title(" Distribution of retweet") #GRAPH FOR Distribution of retweet
# Out:
# Text(0.5, 1.0, ' Distribution of retweet')

# %%
tweets.head(5)
# Out:
#               datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0  2019-08-04 17:02:05     False       False             1          0
# 1  2019-08-04 17:06:11      True       False             0          0
# 2  2019-08-04 17:07:21      True       False             0          0
# 3  2019-08-04 17:20:13     False       False             1          0
# 4  2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            0  The #Article370  & #Article35A  are against th...
# 1            0  After Phulwama Gafoor said in his talk Media d...
# 2            0  y r u instigating people... stop spreading ven...
# 3            0  After observing #bjp  govt in last 5 years, I ...
# 4            1  Always a good thing to listen AGAIN to people ...
#
#      usernameTweet  len_text
# 0         NeeloyWB        27
# 1          raj_ubl        37
# 2       123ashwini        17
# ...

# %%
tweets.loc[tweets['is_retweet']].text.unique().size# unique retweets
# Out:
# 121

# %% [markdown]
# ##### FROM THE ABOVE DATA IT IS CLEAR THAT
# #-> THE 126 PEOPLE TWEETED THEIR OPINION AGAIN ON THE SAME ISSUE
# #->THE 88207 PEOPLE TWEETED ONLY ONCE

# %% [markdown]
# ## GRAPHICAL REPRESENTATION OF TWEETS

# %%
# number of times each tweet appears
counts = tweets.groupby(['text']).size()\
           .reset_index(name='counts')\
           .counts

# define bins for histogram
my_bins = np.arange(0,counts.max()+2, 1)-0.5

# plot histogram of tweet counts
plt.figure()
plt.hist(counts, bins = my_bins)
plt.xlabels = np.arange(1,counts.max()+1, 1)
plt.xlabel('copies of each tweet')
plt.ylabel('frequency')
plt.yscale('log', nonposy='clip')
plt.show()

# %% [markdown]
# ## HASTAGS

# %%
import re

# %%
# DEFINING A FUNCTION FOR IDENTIFING THE WORDS WITH HASTAGS
def find_hashtags(text):
    '''This function will extract hashtags'''
    return re.findall('(#[A-Za-z]+[A-Za-z0-9-_]+)', text)

# %%
#FINDING THE HASTAGS IN THE TEXT
tweets['hashtags'] = tweets.text.apply(find_hashtags)
tweets.head()
# Out:
#               datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0  2019-08-04 17:02:05     False       False             1          0
# 1  2019-08-04 17:06:11      True       False             0          0
# 2  2019-08-04 17:07:21      True       False             0          0
# 3  2019-08-04 17:20:13     False       False             1          0
# 4  2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            0  The #Article370  & #Article35A  are against th...
# 1            0  After Phulwama Gafoor said in his talk Media d...
# 2            0  y r u instigating people... stop spreading ven...
# 3            0  After observing #bjp  govt in last 5 years, I ...
# 4            1  Always a good thing to listen AGAIN to people ...
#
#      usernameTweet  len_text  \
# 0         NeeloyWB        27
# 1          raj_ubl        37
# 2       123ashwini        17
# ...

# %%
tweets['hashtags'].describe()
# Out:
# count             88333
# unique            29721
# top       [#Article370]
# freq              25386
# Name: hashtags, dtype: object

# %% [markdown]
# ##### FROM THE ABOVE DATA IT IS OBSERVED THAT
# #->THE TOP MOST HASTAGS THAT OCCURED IN TWEETS IS ""[#Article370]"".
# #->IT OCCURES "25386" TIMES

# %%
# take the rows from the hashtag columns where there are actually hashtags
hashtags_list_df = tweets.loc[
                       tweets.hashtags.apply(
                           lambda hashtags_list: hashtags_list !=[]
                       ),['hashtags']]

# %%
# create dataframe where each use of hashtag gets its own row
flattened_hashtags_df = pd.DataFrame(
    [hashtag for hashtags_list in hashtags_list_df.hashtags
    for hashtag in hashtags_list],
    columns=['hashtags'])

# %%
tweets.head() # CHECKING THE COLUMN OF HASTAGS
# Out:
#               datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0  2019-08-04 17:02:05     False       False             1          0
# 1  2019-08-04 17:06:11      True       False             0          0
# 2  2019-08-04 17:07:21      True       False             0          0
# 3  2019-08-04 17:20:13     False       False             1          0
# 4  2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            0  The #Article370  & #Article35A  are against th...
# 1            0  After Phulwama Gafoor said in his talk Media d...
# 2            0  y r u instigating people... stop spreading ven...
# 3            0  After observing #bjp  govt in last 5 years, I ...
# 4            1  Always a good thing to listen AGAIN to people ...
#
#      usernameTweet  len_text  \
# 0         NeeloyWB        27
# 1          raj_ubl        37
# 2       123ashwini        17
# ...

# %%
# number of unique hashtags
flattened_hashtags_df['hashtags'].unique().size
# Out:
# 14075

# %%
# count of appearances of each hashtag
popular_hashtags = flattened_hashtags_df.groupby('hashtags').size()\
                                        .reset_index(name='counts')\
                                        .sort_values('counts', ascending=False)\
                                        .reset_index(drop=True)

# %%
# number of times each hashtag appears
counts = flattened_hashtags_df.groupby(['hashtags']).size()\
                              .reset_index(name='counts')\
                              .counts

# define bins for histogram                              
my_bins = np.arange(0,counts.max()+1000,1000)-0.5

# plot histogram of tweet counts
plt.figure()
plt.hist(counts, bins = my_bins)
plt.xlabels = np.arange(1,counts.max()+1000, 1000)
plt.xlabel('hashtag number of appearances')
plt.ylabel('frequency')
plt.yscale('log', nonposy='clip')
plt.show()

# %% [markdown]
# ### COMMON OCCURRED HASTAGS OTHER THAN ""#ARTICLE370"

# %%
tweets['hashtags'].tolist()
# Out:
# [['#Article370',
#   '#Article35A',
#   '#India',
#   '#KashmirParFinalFight',
#   '#IndiaForKashmir',
#   '#IndianarmyinKashmir',
#   '#joyhind'],
#  ['#Article370', '#Article35A'],
#  ['#Article370', '#Article370'],
#  ['#bjp',
#   '#Article370',
#   '#Article35A',
#   '#UCC',
#   '#uniformcivilcode',
#   '#TripleTalaq',
#   '#RamMandir',
#   '#election',
#   '#KashmirParFinalFight',
#   '#IndiaForKashmir'],
#  ['#IndiaForKashmir', '#IndiaWithKashmir', '#Article35A', '#Article370'],
#  ['#Article35A', '#Article370', '#IndiaForKashmir'],
#  ['#Kashmir', '#IndianArmy', '#Article370', '#KashmirBleeds'],
#  ['#Article370', '#KashmirParFinalFight'],
#  ['#Article370'],
#  ['#India',
#   '#IndiaForKashmir',
#   '#Article370',
#   '#Art35A',
#   '#HappyFriendshipDay2019',
#   '#KashmirIssue',
#   '#Kashmir'],
#  ['#IndiaForKashmir', '#kashmir', '#Article370', '#JaiHind', '#JaiBharat'],
#  ['#india', '#Article35A', '#Article370', '#indians', '#kashmir', '#GOI'],
#  ['#Article370',
# ...

# %%
tweets['hashtags'].value_counts()
# Out:
# [#Article370]                                                                                                                                                                                                                                           25386
# []                                                                                                                                                                                                                                                       3471
# [#Article370, #JammuAndKashmir]                                                                                                                                                                                                                          1897
# ...

# %% [markdown]
# #### THE HASTGAS THAT OCCURED FREQUENTLY OTHER THAN "#ARTICLE 370" ARE
#                     ["##JammuAndKashmir", "##KashmirHamaraHai", "#Article35A", "#Kashmir"]

# %% [markdown]
# ### CONVERTING THE DATETIME INTO SERIES OF DATE ,TIME AND MONTH

# %%
tweets['datetime']=pd.to_datetime(tweets['datetime'],errors='coerce')

# %%
tweets['datetime'].describe()
# Out:
# count                   88333
# unique                  57810
# top       2019-08-04 23:42:53
# freq                       14
# first     2019-08-04 17:02:05
# last      2019-08-09 16:56:00
# Name: datetime, dtype: object

# %%
tweets['Year']=tweets['datetime'].dt.year # CONVERTING DATETIME INTO SPECIFIC YEAR
tweets['Month']=tweets['datetime'].dt.month # CONVERTING DATETIME INTO SPECIFIC MONTH
tweets['Date']=tweets['datetime'].dt.date # CONVERTING DATETIME INTO SPECIFIC DATE
tweets['Time']=tweets['datetime'].dt.time # CONVERTING DATETIME INTO SPECIFIC TIME

# %% [markdown]
# #### TWEETS W.R.T THE TIME

# %%
tweets['Time'].value_counts()
# Out:
# 23:42:53    16
# 19:30:00    16
# 06:30:00    15
# 23:39:08    14
# 08:30:00    13
# 23:21:10    13
# 23:33:17    12
# 23:41:21    12
# 23:16:39    12
# 23:09:12    12
# 23:32:38    12
# 23:19:05    11
# 20:30:00    11
# 23:13:54    11
# 00:30:00    11
# 09:30:00    11
# 00:15:00    11
# 23:28:41    11
# 00:10:18    11
# 05:30:00    11
# 23:07:42    11
# 00:02:04    11
# 01:15:00    11
# 23:30:00    11
# 23:26:35    11
# 23:26:11    11
# 23:24:23    11
# 23:16:51    10
# 23:35:54    10
# 23:39:12    10
#             ..
# 01:22:00     1
# 11:48:30     1
# 02:02:56     1
# 18:39:05     1
# 01:33:58     1
# 07:36:47     1
# 05:10:53     1
# 22:48:32     1
# 07:24:28     1
# 17:30:42     1
# 02:33:35     1
# 20:13:33     1
# 03:38:21     1
# 10:52:16     1
# 07:44:44     1
# 04:59:50     1
# 02:05:42     1
# 04:55:51     1
# 17:48:28     1
# 05:59:07     1
# 05:27:36     1
# 20:18:41     1
# 05:54:56     1
# 09:50:42     1
# 04:28:55     1
# 06:31:54     1
# 18:36:45     1
# ...

# %%
tweets['Time'].describe()
# Out:
# count        88333
# unique       43305
# top       23:42:53
# freq            16
# Name: Time, dtype: object

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88333 entries, 0 to 88332
# Data columns (total 14 columns):
# datetime         88333 non-null datetime64[ns]
# is_reply         88333 non-null bool
# is_retweet       88333 non-null bool
# nbr_favorite     88333 non-null int64
# nbr_reply        88333 non-null int64
# nbr_retweet      88333 non-null int64
# text             88333 non-null object
# usernameTweet    88333 non-null object
# len_text         88333 non-null int64
# hashtags         88333 non-null object
# Year             88333 non-null int64
# Month            88333 non-null int64
# Date             88333 non-null object
# Time             88333 non-null object
# dtypes: bool(2), datetime64[ns](1), int64(6), object(5)
# memory usage: 8.3+ MB

# %% [markdown]
# ###### -> Most of the people tweet in between 11:30 to 12:00 at Night,7:30 & 6:30 in the evening
# ###### ->They update thier tweets and opinions when they come back from offices and be free at that time before they go to sleep

# %%
tweets.head(5) #CHECKING THE EXTRA COLUMNS WHICH ARE ADDED
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-08-04 17:02:05     False       False             1          0
# 1 2019-08-04 17:06:11      True       False             0          0
# 2 2019-08-04 17:07:21      True       False             0          0
# 3 2019-08-04 17:20:13     False       False             1          0
# 4 2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            0  The #Article370  & #Article35A  are against th...
# 1            0  After Phulwama Gafoor said in his talk Media d...
# 2            0  y r u instigating people... stop spreading ven...
# 3            0  After observing #bjp  govt in last 5 years, I ...
# 4            1  Always a good thing to listen AGAIN to people ...
#
#      usernameTweet  len_text  \
# 0         NeeloyWB        27
# 1          raj_ubl        37
# 2       123ashwini        17
# ...

# %% [markdown]
# ### WHAT IS THE NUMBER OF TWEETS BASED ON DATE?

# %%
tweets['Date'].value_counts() #CHECKING THE DATE OF THE DATA
# THE DATA COLLECTED ON THE DATES OF 4,5,6,7,9
# Out:
# 2019-08-05    48051
# 2019-08-04    15510
# 2019-08-06    12439
# 2019-08-07     5627
# 2019-08-08     4517
# 2019-08-09     2189
# Name: Date, dtype: int64

# %% [markdown]
#  The tweets are less on "9th august 2019" and more on "5th august 2019"

# %%
tweets['Month'].value_counts() # checking the MONTH of the data
# Out:
# 8    88333
# Name: Month, dtype: int64

# %% [markdown]
#  it is occured in AUGUST

# %%
tweets['Year'].value_counts()# checking the YEAR of the data
# Out:
# 2019    88333
# Name: Year, dtype: int64

# %% [markdown]
# it occurred in 2019

# %%
tweets['Time'].describe() #checking the TIME of the data
# Out:
# count        88333
# unique       43305
# top       23:42:53
# freq            16
# Name: Time, dtype: object

# %%
# CLUBBING THE COLUMNS OG TEXT AND THE LIKES OCCURED IN THE DATA
tweets_likes = tweets.groupby(['text','nbr_favorite']).size().unstack().reset_index()
tweets_likes[:5]
# Out:
# nbr_favorite                                               text    0    1  \
# 0             \n\n"Bois pled well" ho raha hoga.\n#KashmirPa...  NaN  NaN
# 1             \n\n#Article370 \n\nFor years these separatist...  NaN  1.0
# 2                                         \n\n#Article370  gone  1.0  NaN
# 3             \n\n#KashmirParFinalFight  \n#Article370  and ...  1.0  NaN
# 4             \n\n#SAVE_KASHMIR \n#SAVE_HUMANITY \n#SAVE_MY_...  1.0  NaN
#
# nbr_favorite    2   3   4   5   6   7   8  ...  20295  22279  24976  25195  \
# 0             1.0 NaN NaN NaN NaN NaN NaN  ...    NaN    NaN    NaN    NaN
# 1             NaN NaN NaN NaN NaN NaN NaN  ...    NaN    NaN    NaN    NaN
# 2             NaN NaN NaN NaN NaN NaN NaN  ...    NaN    NaN    NaN    NaN
# 3             NaN NaN NaN NaN NaN NaN NaN  ...    NaN    NaN    NaN    NaN
# 4             NaN NaN NaN NaN NaN NaN NaN  ...    NaN    NaN    NaN    NaN
#
# nbr_favorite  27002  28466  33089  38671  41228  67061
# ...

# %%
#checking the likes for every tweets
tweets_likes1 = tweets.groupby(['text','nbr_favorite']).size().reset_index(0)
tweets_likes1[:5]
# Out:
#                                                            text  0
# nbr_favorite
# 2             \n\n"Bois pled well" ho raha hoga.\n#KashmirPa...  1
# 1             \n\n#Article370 \n\nFor years these separatist...  1
# 0                                         \n\n#Article370  gone  1
# 0             \n\n#KashmirParFinalFight  \n#Article370  and ...  1
# 0             \n\n#SAVE_KASHMIR \n#SAVE_HUMANITY \n#SAVE_MY_...  1

# %% [markdown]
# #->THE DATA GET OVERALL 67061 LIKES TWEETS OUT OF 88333 TWEETS

# %% [markdown]
# # LIKES DISTRIBUTION

# %% [markdown]
# The COLUMN  nbr_favourites is normally called as "LIKES"

# %%
# GRAPHICAL REPRESENTATION OF LIKES
sns.kdeplot(tweets['nbr_favorite']).set_title(" Distribution of Likes")
# Out:
# Text(0.5, 1.0, ' Distribution of Likes')

# %% [markdown]
# ### CLEANING OF TEXT DATA

# %%
# NOW SAVING THE DATA INTO OTHER DATAFILE CALLES "TWEETS1" FOR TEXT CLEANING
tweets1=tweets
tweets1.head(5)
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-08-04 17:02:05     False       False             1          0
# 1 2019-08-04 17:06:11      True       False             0          0
# 2 2019-08-04 17:07:21      True       False             0          0
# 3 2019-08-04 17:20:13     False       False             1          0
# 4 2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            0  The #Article370  & #Article35A  are against th...
# 1            0  After Phulwama Gafoor said in his talk Media d...
# 2            0  y r u instigating people... stop spreading ven...
# 3            0  After observing #bjp  govt in last 5 years, I ...
# 4            1  Always a good thing to listen AGAIN to people ...
#
#      usernameTweet  len_text  \
# 0         NeeloyWB        27
# 1          raj_ubl        37
# 2       123ashwini        17
# ...

# %%
type(tweets1['text']) # THE TYPE OF TEXT
# Out:
# pandas.core.series.Series

# %%
tweets1['text'].head(5) #checking the top data of text
# Out:
# 0    The #Article370  & #Article35A  are against th...
# 1    After Phulwama Gafoor said in his talk Media d...
# 2    y r u instigating people... stop spreading ven...
# 3    After observing #bjp  govt in last 5 years, I ...
# 4    Always a good thing to listen AGAIN to people ...
# Name: text, dtype: object

# %%
# DEFING ALL THE FUNCTIONS NEEDED FOR CLEANING THE TEXT
import re # regular expressions
import string # to accept string 
import nltk # it is a text processing libraries for tokenization, parsing, classification, stemming, tagging and semantic reasoning.
from nltk.corpus import stopwords # particular words which are not neccesary in english
from nltk.stem import PorterStemmer# we use stemmer to remove the "ing" of words
def clean_text(text):
    ps=PorterStemmer()
    text1 = re.sub(r'^https?:\/\/.*[\r\n]*', '', text)#remove url
    print(text1)
    text1=re.sub('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE)#remove emojis
    print(text1)
    text1=re.sub("\s+"," ",x) # removing the space
    print(text1)
    text1=re.sub('#[\w]+', '', x) # removing 'hastags'
    print(text1)
    text_cleaned=" ".join([x for x in text1 if x not in string.punctuation])# remove punctuations
    print(text_cleaned)
    text_cleaned=text_cleaned.lower() #converting all words upper cases into lower case
    print(text_cleaned)
    text_cleaned=text_cleaned.split(" ")# splitting the words with space if neccessary
    print(text_cleaned)
    text_tokens=[token for token in text_cleaned if token not in STOPWORDS] # Prints list of all tokens in the document
    stem_words=[ps.stem(stem) for stem in text_tokens ] # the stem of all tokens in the document
    text=" ".join(stem_words)
    text_cleaned=re.sub(' +',' ',text)# for removing the extra space
    return text_cleaned

# %%
tweets1['cleaned_text']=tweets1['text'].apply(lambda x:re.sub('http.*','',x)) # removing the URL
tweets1['cleaned_text']=tweets1['cleaned_text'].apply(lambda x:re.sub("\s+"," ",x))# removing the space
tweets1['cleaned_text'].head(5)
# Out:
# 0    The #Article370 & #Article35A are against the ...
# 1    After Phulwama Gafoor said in his talk Media d...
# 2    y r u instigating people... stop spreading ven...
# 3    After observing #bjp govt in last 5 years, I n...
# 4    Always a good thing to listen AGAIN to people ...
# Name: cleaned_text, dtype: object

# %%
tweets1['cleaned_text'] = tweets1['cleaned_text'].str.replace('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE) ## removing emojis
tweets1['cleaned_text'] = tweets1['cleaned_text'].apply(lambda x:re.sub('#[\w]+', '', x)) # removing '#'
tweets1['cleaned_text'] = tweets1['cleaned_text'].apply(lambda x:re.sub("\s+"," ",x))# removing the space
tweets1['cleaned_text'] = tweets1['cleaned_text'].apply(lambda x: re.sub('[^\x00-\x7F]+',' ',x))## Remove Ascii Characters

# %%
tweets1['cleaned_text'].head(5)
# Out:
# 0    The are against the basic structure and motto ...
# 1    After Phulwama Gafoor said in his talk Media d...
# 2    y r u instigating people... stop spreading ven...
# 3    After observing govt in last 5 years, I never ...
# 4    Always a good thing to listen AGAIN to people ...
# Name: cleaned_text, dtype: object

# %%
tweets1['cleaned_text'].tolist() # to check the reviews
# Out:
# ['The are against the basic structure and motto of the constitution of . Will gonna be historic or misadventure ',
#  'After Phulwama Gafoor said in his talk Media did not support the Pak Army. Otherwise they could have defeated India. So Are you guys getting SMS from Gafoor sab @ZarrarKhuhro Start singing in unison. , ',
#  'y r u instigating people... stop spreading venom...let india witness d history needs to go',
#  'After observing govt in last 5 years, I never believed that . might be scraped Nor , , . But recent developments assures me, these are not just gimmick. ',
#  'Always a good thing to listen AGAIN to people who know... ',
#  'Time to abolish the apartheid , amalgamate Kashmir its people into India. Status quo on Kashmir is over. ',
#  'Jai Hind Dosto. but with filthy blood of terrorism. ',
#  'The very first word of is TEMPORARY pic.twitter.com/Sm8Q0GkbKs',
# ...

# %%
## Below are the default stopwordsin english 
STOPWORDS=stopwords.words('english')
print(STOPWORDS)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
tweets1['cleaned_text']=tweets1['cleaned_text'].apply(lambda cleaned_text:"".join([x for x in cleaned_text if x not in string.punctuation]))
# removing punctuations
tweets1['cleaned_text']=tweets1['cleaned_text'].apply(lambda x:x.lower()) # CONVERTING THE UPPERCASE LETTERS TO LOWERCASE
tweets1['cleaned_text'].head(5)
# Out:
# 0    the are against the basic structure and motto ...
# 1    after phulwama gafoor said in his talk media d...
# 2    y r u instigating people stop spreading venoml...
# 3    after observing govt in last 5 years i never b...
# 4    always a good thing to listen again to people ...
# Name: cleaned_text, dtype: object

# %%
tweets1.head(5) # finally checking the cleaned data
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-08-04 17:02:05     False       False             1          0
# 1 2019-08-04 17:06:11      True       False             0          0
# 2 2019-08-04 17:07:21      True       False             0          0
# 3 2019-08-04 17:20:13     False       False             1          0
# 4 2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            0  The #Article370  & #Article35A  are against th...
# 1            0  After Phulwama Gafoor said in his talk Media d...
# 2            0  y r u instigating people... stop spreading ven...
# 3            0  After observing #bjp  govt in last 5 years, I ...
# 4            1  Always a good thing to listen AGAIN to people ...
#
#      usernameTweet  len_text  \
# 0         NeeloyWB        27
# 1          raj_ubl        37
# 2       123ashwini        17
# ...

# %% [markdown]
# ### IMPORTING ALL THE LIBRARIES

# %%
# !pip install gensim  
#Gensim is a Python library for topic modelling, document indexing and similarity retrieval with large corpora.

# %%
import gensim #Gensim is a Python library for topic modelling, document indexing and similarity retrieval with large corpora. 
from gensim import corpora 
#*Corpora* is a lightweight, fast and scalable corpus library
# it is able to store a collection of raw text documents with additional key-value headers

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
#from gensim import corpora, models
#import gensim
import nltk
##nltk.download("stopwords")


# %autoreload 2

# Visualizations
import plotly.express as px

import matplotlib.pyplot as plt
import seaborn as sns
import re


import gensim
from gensim import corpora

# libraries for visualization
import pyLDAvis
import pyLDAvis.gensim
# Out:
# UsageError: Line magic function `%autoreload` not found.

# %%
#Counters can be used to implement the same algorithms for which other languages commonly use bag or multiset data structures.
from collections import Counter

# %% [markdown]
# ## ANALYZING THE SENTIMENT FOR EACH CLEANED TEXT

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
# DEFINING A FUNCTION TO UNDERSTAND THE SENTENCE SCORE FOR EACH WORD IN A SENTENCE
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    #print(score)
    return score

# %%
# DEFINING A FUNCTION FOR ADDING UP ALL THE SCORES OF EACH WORDS IN A SENTENCE AND DEFINE A VALUE CALLED COMPOUND SCORE
def compound_score(text):
    sc=sentiment_analyzer_scores(text)
    return sc['compound']

# %%
# SENDING ALL THE SENTENCES OF TWEETS FOR ANALYZING SCORE
tweets1['comp_score']=tweets1['cleaned_text'].apply(lambda x:compound_score(x))

# %%
tweets1.head(5) # CHECKING THE COMPOUND SCORE COLUMN
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-08-04 17:02:05     False       False             1          0
# 1 2019-08-04 17:06:11      True       False             0          0
# 2 2019-08-04 17:07:21      True       False             0          0
# 3 2019-08-04 17:20:13     False       False             1          0
# 4 2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            0  The #Article370  & #Article35A  are against th...
# 1            0  After Phulwama Gafoor said in his talk Media d...
# 2            0  y r u instigating people... stop spreading ven...
# 3            0  After observing #bjp  govt in last 5 years, I ...
# 4            1  Always a good thing to listen AGAIN to people ...
#
#      usernameTweet  len_text  \
# 0         NeeloyWB        27
# 1          raj_ubl        37
# 2       123ashwini        17
# ...

# %%
# GRAPHICAL REPRESENTATION OF comp_score
sns.kdeplot(tweets['comp_score']).set_title(" Distribution of comp_score")
# Out:
# Text(0.5, 1.0, ' Distribution of comp_score')

# %%
# DEFINING AN FUNCTION ANALYZING THE EMOTION OF TEXT BY USING COMPOUND SCORE AS REFERENCE
def emotion(score):
    if score>0.5:
        return "positive"
    if score<0.5:
        return "negative"
    if score==0.5:
        return "neutral"

# %% [markdown]
# #### WE DEFINE THE SENTIMENT BY TAKING A THRESHOLD AS "0.5" AND DEFINING THE EMOTIONS AS
# -> ">0.5" AS POSITIVE RESPONSE -> "<0.5" AS NEGATIVE RESPONSE -> "=0.5" AS NEUTRAL RESPONSE

# %%
tweets1['sentiment']=tweets1['comp_score'].apply(lambda x:emotion(x)) # storing it into a new column called sentiment
tweets1.sample(5)
# Out:
#                  datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 12357 2019-08-04 23:44:30     False       False             4          0
# 29569 2019-08-05 02:01:13      True       False             2          0
# 88265 2019-08-09 14:28:35     False       False             0          0
# 76575 2019-08-07 01:54:05     False       False             2          1
# 11821 2019-08-04 23:42:00     False       False             0          0
#
#        nbr_retweet                                               text  \
# 12357            0  # Article35A  #Article370  - Time to update :)...
# 29569            0  If you are not sure what #Article35A  is, read...
# 88265            0  helmets to be made compulsory in #kashmir  fro...
# 76575            0  My login password reset was due on 04 Aug 2019...
# 11821            0  Another sudden storm after Demontisation   #Ar...
#
#         usernameTweet  len_text  \
# 12357   chaitanyacool        19
# 29569      mytentaran        26
# ...

# %%
tweets1['sentiment'].describe()
# Out:
# count        88333
# unique           2
# top       negative
# freq         63396
# Name: sentiment, dtype: object

# %%
sns.countplot(tweets1['sentiment']).set_title("Distribution of Sentiment")
# Out:
# Text(0.5, 1.0, 'Distribution of Sentiment')

# %% [markdown]
# -> THERE ARE MORE "NEGATIVE TWEETS" THAN THE POSITIVE TWEETS

# %% [markdown]
# ### How does the sentiment vary over time?

# %%
tweets1['Time'] = tweets1['datetime'].dt.strftime('%H')
tweets1['Time']=tweets['Time'].apply(lambda x:float(x)) # CONVERTING THE STRING INTO FLOAT BY USING USING APPLY FUNCTION

# %%
tweets1['Date']=pd.to_datetime(tweets1['Date'],errors='coerce')
tweets1['Date']=tweets1["Date"].apply(lambda x:str(x)) # CONVERTING THE OBJECT INTO STRING BY USING APPLY FUNCTION

# %%
tweets1.info() #CHECKING WHETHER THE DATATYPES CHANGED OR NOT
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88333 entries, 0 to 88332
# Data columns (total 20 columns):
# datetime          88333 non-null datetime64[ns]
# is_reply          88333 non-null bool
# is_retweet        88333 non-null bool
# nbr_favorite      88333 non-null int64
# nbr_reply         88333 non-null int64
# nbr_retweet       88333 non-null int64
# text              88333 non-null object
# usernameTweet     88333 non-null object
# len_text          88333 non-null int64
# hashtags          88333 non-null object
# Year              88333 non-null int64
# Month             88333 non-null int64
# Date              88333 non-null object
# Time              88333 non-null float64
# cleaned_text      88333 non-null object
# comp_score        88333 non-null float64
# sentiment         88333 non-null object
# cleaned_tweets    88333 non-null object
# time              88333 non-null float64
# Datee             88333 non-null object
# ...

# %%
#GRAPHICAL REPRESENTATION OF SENTIMENT W.R.T TIME AND SENTIMENT
sns.barplot(x='Time',y='Date',hue='sentiment',data=tweets1)

# %% [markdown]
# ### NOW CHECKING THE POSITIVE AND NEGATIVE FROM THE SENTIMENT

# %%
positive_tweets=tweets1.loc[tweets1['sentiment']=='positive','cleaned_text'].tolist()# storing in a new name THE POSITIVE TWEETS
positive_tweets[0:5]
# Out:
# ['yes am sure is waking up now it should have been much much earlier pictwittercompozlthhqe1',
#  'people of please dont add fuel to fire by saying are going away this belligerent nature is not helping anyone use your words wisely and help our fellow in stay calm we dont know what is going on so wait for to announce',
#  'good morning guys yesterday kashmiris identity were separate but from now 5th of augusttheir identity will be same as ours  lets enjoy this day and always have trust on modi  shah jodi pictwittercomjjtjc7hfgb',
#  'india as a country is gonna change forever today the indian govt blessed with a strong mandate is finally on the verge of abolishing finally we will have a kashmir free from terrorists and separatists',
#  ' kashmirparfinalfight we need control of the area mainly for mitigate aftermath peaceful life for all communities end 35a enjoy the gift of nature stop funds for violence secure borders from dragon a fly ']

# %%
negative_tweets=tweets1.loc[tweets1['sentiment']=='negative','cleaned_text'].tolist()# STORING ALL NEGATIVE TWEETS IN A NEW NAME
negative_tweets[0:5]
# Out:
# ['the are against the basic structure and motto of the constitution of  will gonna be historic or misadventure ',
#  'after phulwama gafoor said in his talk media did not support the pak army otherwise they could have defeated india so are you guys getting sms from gafoor sab zarrarkhuhro start singing in unison  ',
#  'y r u instigating people stop spreading venomlet india witness d history needs to go',
#  'after observing govt in last 5 years i never believed that  might be scraped nor    but recent developments assures me these are not just gimmick ',
#  'always a good thing to listen again to people who know ']

# %%
neutral_tweets=tweets1.loc[tweets1['sentiment']=='neutral','cleaned_text'].tolist()# STORING ALL NEUTRAL TWEETS IN A NEW NAME
neutral_tweets[0:5]
# Out:
# []

# %% [markdown]
# -> THERE IS NO NEUTRAL TWEETSFROM THE TEXT

# %%
# DEFINING A FUNCTION TO GET TOP WORDS THAT FREQUENTLY USED IN ALL TWEETS
def getMostCommon(cleaned_text,topn=20):
    text_cleaned=" ".join(cleaned_text)
    tokenised_tweets=text_cleaned.split(" ")
    freq_counter=Counter(tokenised_tweets)
    return freq_counter.most_common(topn)

# %%
top_25_positive_tweets=getMostCommon(positive_tweets,20)# seeing the top 20 positive tweets frequently occurs
top_25_positive_tweets
# Out:
# [('', 31387),
#  ('the', 21696),
#  ('of', 18423),
#  ('to', 17324),
#  ('and', 14573),
#  ('in', 10494),
#  ('a', 10292),
#  ('is', 9866),
#  ('for', 9034),
#  ('this', 6521),
#  ('india', 6093),
#  ('you', 5374),
#  ('narendramodi', 4841),
#  ('will', 4596),
#  ('amitshah', 4539),
#  ('kashmir', 4517),
#  ('it', 4516),
#  ('on', 4257),
#  ('be', 4099),
#  ('i', 3970)]

# %%
top_25_negative_tweets=getMostCommon(negative_tweets,20)# seeing the top 20 negative tweets frequently occurs
top_25_negative_tweets
# Out:
# [('', 73877),
#  ('the', 40372),
#  ('of', 34337),
#  ('to', 30499),
#  ('and', 23729),
#  ('in', 22461),
#  ('is', 20947),
#  ('a', 17117),
#  ('for', 12303),
#  ('kashmir', 12086),
#  ('on', 11615),
#  ('india', 10842),
#  ('this', 9616),
#  ('it', 9356),
#  ('will', 8722),
#  ('you', 8579),
#  ('be', 8267),
#  ('are', 7328),
#  ('by', 7191),
#  ('one', 7108)]

# %%
top_50_positive_tweets=getMostCommon(positive_tweets,50)# seeing the top 50 positive tweets frequently occurs
top_50_positive_tweets
# Out:
# [('', 31387),
#  ('the', 21696),
#  ('of', 18423),
#  ('to', 17324),
#  ('and', 14573),
#  ('in', 10494),
#  ('a', 10292),
#  ('is', 9866),
#  ('for', 9034),
#  ('this', 6521),
#  ('india', 6093),
#  ('you', 5374),
#  ('narendramodi', 4841),
#  ('will', 4596),
#  ('amitshah', 4539),
#  ('kashmir', 4517),
#  ('it', 4516),
#  ('on', 4257),
#  ('be', 4099),
#  ('i', 3970),
#  ('by', 3812),
#  ('jk', 3734),
#  ('are', 3561),
#  ('with', 3551),
#  ('that', 3518),
#  ('now', 3250),
#  ('we', 3114),
#  ('all', 3078),
#  ('decision', 3071),
#  ('one', 3024),
#  ('ji', 2846),
#  ('has', 2795),
#  ('from', 2753),
#  ('have', 2733),
#  ('people', 2560),
#  ('as', 2518),
#  ('not', 2500),
#  ('historic', 2413),
#  ('its', 2310),
#  ('congratulations', 2308),
#  ('was', 2287),
#  ('370', 2260),
#  ('day', 2209),
#  ('indian', 2125),
#  ('article', 2080),
#  ('what', 2052),
#  ('article370', 2046),
#  ('but', 1968),
#  ('today', 1968),
#  ('our', 1961)]

# %%
top_50_negative_tweets=getMostCommon(positive_tweets,50)# seeing the top 50 negative tweets frequently occurs
top_50_negative_tweets
# Out:
# [('', 31387),
#  ('the', 21696),
#  ('of', 18423),
#  ('to', 17324),
#  ('and', 14573),
#  ('in', 10494),
#  ('a', 10292),
#  ('is', 9866),
#  ('for', 9034),
#  ('this', 6521),
#  ('india', 6093),
#  ('you', 5374),
#  ('narendramodi', 4841),
#  ('will', 4596),
#  ('amitshah', 4539),
#  ('kashmir', 4517),
#  ('it', 4516),
#  ('on', 4257),
#  ('be', 4099),
#  ('i', 3970),
#  ('by', 3812),
#  ('jk', 3734),
#  ('are', 3561),
#  ('with', 3551),
#  ('that', 3518),
#  ('now', 3250),
#  ('we', 3114),
#  ('all', 3078),
#  ('decision', 3071),
#  ('one', 3024),
#  ('ji', 2846),
#  ('has', 2795),
#  ('from', 2753),
#  ('have', 2733),
#  ('people', 2560),
#  ('as', 2518),
#  ('not', 2500),
#  ('historic', 2413),
#  ('its', 2310),
#  ('congratulations', 2308),
#  ('was', 2287),
#  ('370', 2260),
#  ('day', 2209),
#  ('indian', 2125),
#  ('article', 2080),
#  ('what', 2052),
#  ('article370', 2046),
#  ('but', 1968),
#  ('today', 1968),
#  ('our', 1961)]

# %%
# CHECKING ALL THE WORDS IN POSITIVE AND NEGATIVE WORDS AND STORED IT IN NEW NAME
pos_tweets=[val[0] for val in top_25_positive_tweets]
print(pos_tweets)
neg_tweets=[val[0] for val in top_25_negative_tweets]
print(neg_tweets)
# Out:
# ['', 'the', 'of', 'to', 'and', 'in', 'a', 'is', 'for', 'this', 'india', 'you', 'narendramodi', 'will', 'amitshah', 'kashmir', 'it', 'on', 'be', 'i']
# ['', 'the', 'of', 'to', 'and', 'in', 'is', 'a', 'for', 'kashmir', 'on', 'india', 'this', 'it', 'will', 'you', 'be', 'are', 'by', 'one']

# %%
set(neg_tweets) - set(pos_tweets) # CHECKING WORDS OTHER THAN NEGATIVE AND POSITIVE WORDS
# Out:
# {'are', 'by', 'one'}

# %%
set(pos_tweets) - set(neg_tweets) # CHECKING WORDS OTHER THAN POSITIVE AND NEGATIVE WORDS
# Out:
# {'amitshah', 'i', 'narendramodi'}

# %% [markdown]
# ## BAG OF WORDS

# %% [markdown]
# ->An n-gram is a contiguous sequence of n items from a given sample of text or speech.
# ->Using Latin numerical prefixes,
# ->1.)an n-gram of size 1 is referred to as a "unigram";
# ->2.)size 2 is a "bigram" (or, less commonly, a "digram");
# ->3.)size 3 is a "trigram".

# %% [markdown]
# ### CHECKING THE GRAPHS OF UNIGRAMS

# %%
#DEFINING A FUNCTION TO CHECK THE WORDS THAT MOST COMMONLY OCCURING IN TOP 50 WORDS
def plotMostCommonWords(cleaned_text,topn=50,title="Positive Tweets",color="blue",axis=None):
    top_words=getMostCommon(cleaned_text,topn=topn)
    data=pd.DataFrame()
    data['words']=[val[0] for val in top_words]
    data['freq']=[val[1] for val in top_words]
    if axis!=None:
        sns.barplot(y='words',x='freq',data=data,color=color,ax=axis).set_title(title+" top "+str(topn))
    else:
        sns.barplot(y='words',x='freq',data=data,color=color).set_title(title+" top "+str(topn))

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 12,8 ## Sets the heigth and width of image
fig,ax=plt.subplots(1,2)
fig.subplots_adjust(wspace=0.5) #Adjusts the space between the two plots
plotMostCommonWords(positive_tweets,50,"Positive Review Unigrams",axis=ax[0])

plotMostCommonWords(negative_tweets,50,"Negative Review Unigrams",color="red",axis=ax[1])

# %% [markdown]
# ### CHECKING THE NUMBER OF BIGRAMS

# %%
def generateNGram(cleaned_text,n=2):# bigram
    tokens=cleaned_text.split(" ")
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return ["_".join(ngram) for ngram in ngrams]

# %%
positive_tweets_bigrams=[" ".join(generateNGram(cleaned_text)) for cleaned_text in positive_tweets]
negative_tweets_bigrams=[" ".join(generateNGram(cleaned_text)) for cleaned_text in negative_tweets]

# %%
positive_tweets_bigrams[0:5]
# Out:
# ['yes_am am_sure sure_is is_waking waking_up up_now now_it it_should should_have have_been been_much much_much much_earlier earlier_pictwittercompozlthhqe1',
#  'people_of of_please please_dont dont_add add_fuel fuel_to to_fire fire_by by_saying saying_are are_going going_away away_this this_belligerent belligerent_nature nature_is is_not not_helping helping_anyone anyone_use use_your your_words words_wisely wisely_and and_help help_our our_fellow fellow_in in_stay stay_calm calm_we we_dont dont_know know_what what_is is_going going_on on_so so_wait wait_for for_to to_announce',
#  'good_morning morning_guys guys_yesterday yesterday_kashmiris kashmiris_identity identity_were were_separate separate_but but_from from_now now_5th 5th_of of_augusttheir augusttheir_identity identity_will will_be be_same same_as as_ours ours_ _lets lets_enjoy enjoy_this this_day day_and and_always always_have have_trust trust_on on_modi modi_ _shah shah_jodi jodi_pictwittercomjjtjc7hfgb',
# ...

# %%
top_20_positive_bigrams=getMostCommon(positive_tweets_bigrams,topn=20)
top_20_positive_bigrams
# Out:
# [('_', 4142),
#  ('of_the', 2027),
#  ('_article370', 1995),
#  ('of_india', 1651),
#  ('in_the', 1643),
#  ('article_370', 1598),
#  ('thank_you', 1381),
#  ('this_is', 1310),
#  ('for_the', 1233),
#  ('to_be', 1145),
#  ('to_the', 1130),
#  ('narendramodi_amitshah', 1100),
#  ('narendramodi_ji', 1066),
#  ('of_', 1062),
#  ('will_be', 1050),
#  ('amitshah_ji', 916),
#  ('congratulations_to', 899),
#  ('people_of', 897),
#  ('of_jk', 841),
#  ('is_the', 841)]

# %%
top_20_negative_bigrams=getMostCommon(negative_tweets_bigrams,topn=20)
top_20_negative_bigrams
# Out:
# [('_', 6908),
#  ('_article370', 4861),
#  ('article_370', 4172),
#  ('of_the', 3530),
#  ('in_the', 3042),
#  ('of_india', 2646),
#  ('to_be', 2424),
#  ('of_', 2406),
#  ('will_be', 2263),
#  ('jammu_and', 2182),
#  ('and_kashmir', 2162),
#  ('this_is', 1959),
#  ('in_kashmir', 1714),
#  ('amit_shah', 1702),
#  ('union_territory', 1588),
#  ('is_a', 1518),
#  ('scrapping_of', 1511),
#  ('has_been', 1470),
#  ('it_is', 1446),
#  ('abrogation_of', 1439)]

# %%
# GRAPHICAL REPRESENTATION OF BIGRAMS
rcParams['figure.figsize'] = 15,20
fig,ax=plt.subplots(1,2)
fig.subplots_adjust(wspace=1) #Adjusts the space between the two plots
plotMostCommonWords(positive_tweets_bigrams,50,"Positive Tweets Bigrams",axis=ax[0])

plotMostCommonWords(negative_tweets_bigrams,50,"Negative Tweets Bigrams",color="red",axis=ax[1])

# %% [markdown]
# ### CHECKING THE NUMBER OF TRIGRAMS

# %%
def generateNGram(cleaned_text,n=3):# trigram
    tokens=cleaned_text.split(" ")
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return ["_".join(ngram) for ngram in ngrams]

# %%
positive_tweets_trigrams=[" ".join(generateNGram(cleaned_text)) for cleaned_text in positive_tweets]
negative_tweets_trigrams=[" ".join(generateNGram(cleaned_text)) for cleaned_text in negative_tweets]

# %%
top_20_positive_trigrams=getMostCommon(positive_tweets_trigrams,topn=20)
top_20_positive_trigrams
# Out:
# [('__', 2988),
#  ('jammu_and_kashmir', 530),
#  ('the_people_of', 456),
#  ('home_minister_amitshah', 372),
#  ('jai_hind_', 337),
#  ('narendramodi_ji_and', 331),
#  ('thank_you_narendramodi', 326),
#  ('one_nation_one', 322),
#  ('this_is_the', 299),
#  ('special_status_to', 293),
#  ('of_article_370', 293),
#  ('and_home_minister', 289),
#  ('prime_minister_narendramodi', 281),
#  ('congratulations_to_all', 275),
#  ('part_of_india', 274),
#  ('one_of_the', 261),
#  ('narendramodi_and_amitshah', 245),
#  ('people_of_jk', 239),
#  ('narendramodi_ji_amitshah', 229),
#  ('amitshah_ji_for', 219)]

# %%
top_20_negative_trigrams=getMostCommon(negative_tweets_trigrams,topn=20)
top_20_negative_trigrams
# Out:
# [('__', 4164),
#  ('jammu_and_kashmir', 2056),
#  ('one_nation_one', 947),
#  ('of_article_370', 762),
#  ('one_flag_one', 731),
#  ('a_union_territory', 553),
#  ('in_rajya_sabha', 547),
#  ('the_people_of', 516),
#  ('of_jammu_and', 480),
#  ('part_of_india', 471),
#  ('jai_hind_', 464),
#  ('nation_one_constitution', 457),
#  ('abrogation_of_', 424),
#  ('article_370_', 423),
#  ('the_abrogation_of', 422),
#  ('flag_one_nation', 411),
#  ('to_be_a', 407),
#  ('scrapping_of_', 385),
#  ('home_minister_amit', 384),
#  ('in_lok_sabha', 381)]

# %%
# GRAPHICAL REPRESENTATION OF TRIGRAMS
rcParams['figure.figsize'] = 15,20
fig,ax=plt.subplots(1,2)
fig.subplots_adjust(wspace=1) #Adjusts the space between the two plots
plotMostCommonWords(positive_tweets_trigrams,50,"Positive Tweets trigrams",axis=ax[0])

plotMostCommonWords(negative_tweets_trigrams,50,"Negative Tweets trigrams",color="red",axis=ax[1])

# %% [markdown]
# ###  CHECKING THE NUMBER OF TIMES IN 4-GRAM (OR) MOREGRAMS

# %%
def generateNGram(cleaned_text,n=4):
    tokens=cleaned_text.split(" ")
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return ["_".join(ngram) for ngram in ngrams]

# %%
positive_tweets_moregrams=[" ".join(generateNGram(cleaned_text)) for cleaned_text in positive_tweets]
negative_tweets_moregrams=[" ".join(generateNGram(cleaned_text)) for cleaned_text in negative_tweets]

# %%
top_20_positive_moregrams=getMostCommon(positive_tweets_moregrams,topn=20)
top_20_positive_moregrams=getMostCommon(positive_tweets_moregrams,topn=20)

# %%
rcParams['figure.figsize'] = 15,20
fig,ax=plt.subplots(1,2)
fig.subplots_adjust(wspace=1) #Adjusts the space between the two plots
plotMostCommonWords(positive_tweets_moregrams,50,"Positive Tweets moregrams",axis=ax[0])

plotMostCommonWords(negative_tweets_moregrams,50,"Negative Tweets moregrams",color="red",axis=ax[1])

# %% [markdown]
# ### WORD CLOUD

# %% [markdown]
# ->A Word Cloud is a visual representation of text data in the form of tags, which are typically single words whose importance is visualized by way of their size and color.
# ->The first step in visualizing data as a Word Cloud is to analyze the text and retrieve the frequency of each word within the text.

# %%
# GRAPH FOR MOST COMMON WORDS
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wordcloud = WordCloud(height=2000, width=2000, stopwords=set(stopwords.words('english')), background_color='white')
wordcloud = wordcloud.generate(' '.join(tweets1['cleaned_text'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common tweets")
plt.axis('off')
plt.show()

# %%
# GRAPH FOR MOST POSITIVE WORDS
from wordcloud import WordCloud
wordcloud = WordCloud(height=2000, width=2000, stopwords=set(stopwords.words('english')), background_color='white')
wordcloud = wordcloud.generate(' '.join(tweets1.loc[tweets1['sentiment']=='positive','cleaned_text'].tolist()))
plt.imshow(wordcloud)
plt.title("Positive words for Tweets")#positive tweets
plt.axis('off')
plt.show()

# %%
# GRAPH FOR MOST NEGATIVE WORDS
wordcloud = WordCloud(height=2000, width=2000,stopwords=set(stopwords.words('english')), background_color='white')
wordcloud = wordcloud.generate(' '.join(tweets1.loc[tweets1['sentiment']=='negative','cleaned_text'].tolist()))
plt.imshow(wordcloud)
plt.title("Negative words for Tweets")#negative tweets
plt.axis('off')
plt.show()

# %% [markdown]
# ## Let us first tokenise the words and remove stopwords and punctuations. and find the number of clusters by the elbow method

# %%
# load all necessary libraries
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

pd.set_option('max_colwidth', 100)

# %%
import string
from nltk.corpus import stopwords
from nltk import PorterStemmer as Stemmer

# %%
tweets1.head(5)
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-08-04 17:02:05     False       False             1          0
# 1 2019-08-04 17:06:11      True       False             0          0
# 2 2019-08-04 17:07:21      True       False             0          0
# 3 2019-08-04 17:20:13     False       False             1          0
# 4 2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet  \
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
#
#                                                                                                   text  \
# 0  The #Article370  & #Article35A  are against the basic structure and motto of the constitution of...
# 1  After Phulwama Gafoor said in his talk Media did not support the Pak Army. Otherwise they could ...
# 2  y r u instigating people... stop spreading venom...let india witness d history #Article370   #Ar...
# ...

# %%
tweets1['cleaned_text'].tolist()
# Out:
# ['the are against the basic structure and motto of the constitution of  will gonna be historic or misadventure ',
#  'after phulwama gafoor said in his talk media did not support the pak army otherwise they could have defeated india so are you guys getting sms from gafoor sab zarrarkhuhro start singing in unison  ',
#  'y r u instigating people stop spreading venomlet india witness d history needs to go',
#  'after observing govt in last 5 years i never believed that  might be scraped nor    but recent developments assures me these are not just gimmick ',
#  'always a good thing to listen again to people who know ',
#  'time to abolish the apartheid  amalgamate kashmir its people into india status quo on kashmir is over ',
#  'jai hind dosto but with filthy blood of terrorism ',
#  'the very first word of is temporary pictwittercomsm8q0gkbks',
# ...

# %%
STOPWORDS=stopwords.words("english")
STOPWORDS
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
test_doc="india as a country is gonna change forever today the indian govt blessed with a strong mandate is finally on the verge of abolishing finally we will have a kashmir free from terrorists and separatists"
## Remove punctuation
test_doc_cleaned="".join([x for x in test_doc if x not in string.punctuation])
test_doc_cleaned
# Out:
# 'india as a country is gonna change forever today the indian govt blessed with a strong mandate is finally on the verge of abolishing finally we will have a kashmir free from terrorists and separatists'

# %%
## Lower case all words
test_doc_cleaned=test_doc_cleaned.lower()
test_doc_cleaned
# Out:
# 'india as a country is gonna change forever today the indian govt blessed with a strong mandate is finally on the verge of abolishing finally we will have a kashmir free from terrorists and separatists'

# %%
## Let us remove the stopwords
test_tokens=test_doc_cleaned.split(" ")
test_tokens=[token for token in test_tokens if token not in STOPWORDS]
test_tokens
# Out:
# ['india',
#  'country',
#  'gonna',
#  'change',
#  'forever',
#  'today',
#  'indian',
#  'govt',
#  'blessed',
#  'strong',
#  'mandate',
#  'finally',
#  'verge',
#  'abolishing',
#  'finally',
#  'kashmir',
#  'free',
#  'terrorists',
#  'separatists']

# %%
## Stem the words
from nltk.stem import PorterStemmer
ps = PorterStemmer() 
test_doc_cleaned=" ".join([ps.stem(token) for token in test_tokens])
test_doc_cleaned
# Out:
# 'india countri gonna chang forev today indian govt bless strong mandat final verg abolish final kashmir free terrorist separatist'

# %%
#DEFINING A FUNCTION FOR ALL THE STEPS SHOWN FOR INDIVIDUAL PROCESS TO CLEAN ALL THE TEXT
import string   
import re

def clean_text(text):
    ps=PorterStemmer()
    text = text.translate(str.maketrans({key: " {0} ".format(key) for key in string.punctuation}))
    #remove extra white space
    
    text_cleaned="".join([x for x in text if x not in string.punctuation])
    
    text_cleaned=re.sub(' +', ' ', text_cleaned)
    text_cleaned=text_cleaned.lower()
    tokens=text_cleaned.split(" ")
    tokens=[token for token in tokens if token not in STOPWORDS]
    text_cleaned=" ".join([ps.stem(token) for token in tokens])
    
    
    return text_cleaned


print(clean_text(test_doc))
# Out:
# india countri gonna chang forev today indian govt bless strong mandat final verg abolish final kashmir free terrorist separatist

# %%
# SAVING THE CLEANED TEXT INTO A NEW COLUMN CALLED "CLEANED_TWEETS"
tweets1['cleaned_tweets']=tweets1['cleaned_text'].apply(lambda x:clean_text(x))
tweets1.head(5)
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-08-04 17:02:05     False       False             1          0
# 1 2019-08-04 17:06:11      True       False             0          0
# 2 2019-08-04 17:07:21      True       False             0          0
# 3 2019-08-04 17:20:13     False       False             1          0
# 4 2019-08-04 17:25:19     False       False             0          0
#
#    nbr_retweet  \
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
#
#                                                                                                   text  \
# 0  The #Article370  & #Article35A  are against the basic structure and motto of the constitution of...
# 1  After Phulwama Gafoor said in his talk Media did not support the Pak Army. Otherwise they could ...
# 2  y r u instigating people... stop spreading venom...let india witness d history #Article370   #Ar...
# ...

# %% [markdown]
# ### Let us look at the most common words in tweets - building a word cloud.

# %%
# GRAPH FOR POSITIVE WORDS
from wordcloud import WordCloud
wordcloud = WordCloud(height=2000, width=2000, stopwords=set(stopwords.words('english')), background_color='white')
wordcloud = wordcloud.generate(' '.join(tweets1.loc[tweets1['sentiment']=='positive','cleaned_tweets'].tolist()))
plt.imshow(wordcloud)
plt.title("Positive words in tweets")
plt.axis('off')
plt.show()

# %%
# GRAPH FOR NEGATIVE WORDS
wordcloud = WordCloud(height=2000, width=2000, stopwords=set(stopwords.words('english')), background_color='white')
wordcloud = wordcloud.generate(' '.join(tweets1.loc[tweets1['sentiment']=='negative','cleaned_tweets'].tolist()))
plt.imshow(wordcloud)
plt.title("Negative words in tweets")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Let us build a "ELBOW" model for finding clusters

# %% [markdown]
# ->The elbow method is a heuristic method of interpretation and validation of consistency within cluster analysis designed to help finding the appropriate number of clusters in a dataset.

# %%
#IMPORT ALL THE LIBRARIES
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
#Creating bag of words model using count vectorizer function
bow=CountVectorizer()
bow_twttes1 = bow.fit_transform(tweets1['cleaned_tweets'])

# %%
len(bow.vocabulary_) # Get number of words in vocabulary
# Out:
# 60563

# %%
## Let us take an sms and see how BoW modle has transformed it

tweet=tweets1.iloc[10]['cleaned_tweets']
tweet
# Out:
# ' narendramodi sir first time feel power vote '

# %%
tweet_transform=bow.transform([tweet])
print(tweet_transform) # returns the row number and column number of the cells which have 1 as value
# Out:
#   (0, 13257)	1
#   (0, 13453)	1
#   (0, 25175)	1
#   (0, 48239)	1
#   (0, 53413)	1
#   (0, 56602)	1
#   (0, 59045)	1

# %%
# SEEING THE TWEET NAME
j = bow.transform([tweet]).toarray()[0]

print('index\tterm\tcount')
for i in range(len(j)):
    if j[i] != 0:
        print(i, bow.get_feature_names()[i],j[i],sep='\t')
# Out:
# index	term	count
# 13257	feel	1
# 13453	first	1
# 25175	narendramodi	1
# 48239	power	1
# 53413	sir	1
# 56602	time	1
# 59045	vote	1

# %% [markdown]
# ##### WHAT IS TDF-IDF?
# ->TF-IDF are word frequency scores that try to highlight words that are more interesting
# ->The TfidfVectorizer will tokenize documents, learn the vocabulary and inverse document frequency weightings,
# and allow you to encode new documents

# %%
tfidf = TfidfVectorizer(
    min_df = 10,
    max_df = 0.99,
    max_features = 10000,
    stop_words = 'english'
)
tfidf.fit(tweets1.cleaned_tweets)
text = tfidf.transform(tweets1.cleaned_tweets)

# %%
from sklearn.cluster import MiniBatchKMeans
def find_optimal_clusters(tweets1, max_k):
    iters = range(1, max_k+12, 4)
    
    sse = []
    for k in iters:
        sse.append(MiniBatchKMeans(n_clusters=k, init_size=1024, batch_size=2048, random_state=10).fit(tweets1).inertia_)
        print('Fit {} clusters'.format(k))
        
    f, ax = plt.subplots(1, 1)
    ax.plot(iters, sse, marker='o')
    ax.set_xlabel('Cluster Centers')
    ax.set_xticks(iters)
    ax.set_xticklabels(iters)
    ax.set_ylabel('SSE')
    ax.set_title('SSE by Cluster Center Plot')
    
find_optimal_clusters(text,20)
# Out:
# Fit 1 clusters
# Fit 5 clusters
# Fit 9 clusters
# Fit 13 clusters
# Fit 17 clusters
# Fit 21 clusters
# Fit 25 clusters
# Fit 29 clusters

# %% [markdown]
# ### By Elbow Method where there are totally 21 clusters

# %%
clusters = MiniBatchKMeans(n_clusters=21, init_size=1024, batch_size=2048, random_state=20).fit_predict(text)

# %%
import matplotlib.cm as cm
def plot_tsne_pca(data, labels):
    max_label = max(labels)
    max_items = np.random.choice(range(tweets1.shape[0]), size=3000, replace=False)
    
    pca = PCA(n_components=2).fit_transform(data[max_items,:].todense())
    tsne = TSNE().fit_transform(PCA(n_components=50).fit_transform(data[max_items,:].todense()))
    
    
    idx = np.random.choice(range(pca.shape[0]), size=300, replace=False)
    label_subset = labels[max_items]
    label_subset = [cm.hsv(i/max_label) for i in label_subset[idx]]
    
    f, ax = plt.subplots(1, 2, figsize=(14, 6))
    
    ax[0].scatter(pca[idx, 0], pca[idx, 1], c=label_subset)
    ax[0].set_title('PCA Cluster Plot')
    
    ax[1].scatter(tsne[idx, 0], tsne[idx, 1], c=label_subset)
    ax[1].set_title('TSNE Cluster Plot')
    
plot_tsne_pca(text, clusters)

# %% [markdown]
# ->PCA essentially works by separating points as far as possible
# ->TSNE(t-Distributed Stochastic Neighbor Embedding) is essentially works by grouping points as close as possible
# ->TSNE will form cluster only when data is non-sparse

# %%
def get_top_keywords(tweets1, clusters, labels, n_terms):
    df = pd.DataFrame(tweets1.todense()).groupby(clusters).mean()
    
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([labels[t] for t in np.argsort(r)[-n_terms:]]))
            
get_top_keywords(text, clusters, tfidf.get_feature_names(), 21)
# Out:
# Cluster 0
# today,bjp,amitshah,remov,taken,peac,peopl,histor,state,article370,kashmir,narendramodi,revok,indian,india,jk,scrap,support,decis,modi,govt
#
# Cluster 1
# need,state,amitshah,govern,dont,nation,kashmir,countri,know,abrog,remov,modi,revok,right,jk,like,kashmiri,pakistan,today,scrap,india
#
# Cluster 2
# narendramodi,peopl,explain,amitshah,indian,dear,india,kashmir,remov,dont,union,territori,28,state,children,correct,text,book,civic,geographi,pleas
#
# Cluster 3
# mehboobamufti,article370,sushmaswaraj,internet,like,pm,peopl,narendramodi,know,india,hour,kashmir,support,today,dont,read,scrap,day,rahulgandhi,wait,tweet
#
# Cluster 4
# revok,flag,decis,narendramodi,today,congratul,scrap,armi,moment,modi,right,pakistan,histori,kashmiri,constitut,govern,kashmir,india,everi,proud,indian
#
# Cluster 5
# issu,peopl,kashmiri,integr,ladakh,chang,occupi,revok,kanyakumari,buy,scrap,2019,final,special,state,statu,pakistan,free,india,jammu,kashmir
#
# Cluster 6
# ...

# %%
tweets1=tweets1[~pd.isnull(tweets1['cleaned_tweets'])]
tweets1.shape
#dictionary = corpora.Dictionary(data['cleaned_noun_adj_review'].tolist())
# Out:
# (88333, 18)

# %%
corpus=tweets1['cleaned_tweets'].tolist()# we use corpusfor topic modelling

# %%
corpus #checking all the list of cleaned tweets
# Out:
# ['basic structur motto constitut gonna histor misadventur ',
#  'phulwama gafoor said talk media support pak armi otherwis could defeat india guy get sm gafoor sab zarrarkhuhro start sing unison ',
#  'r u instig peopl stop spread venomlet india wit histori need go',
#  'observ govt last 5 year never believ might scrape recent develop assur gimmick ',
#  'alway good thing listen peopl know ',
#  'time abolish apartheid amalgam kashmir peopl india statu quo kashmir ',
#  'jai hind dosto filthi blood terror ',
#  'first word temporari pictwittercomsm8q0gkbk',
#  'tweet show lack understand subject think local leadership support abrog plu keep loop hp avoid potenti backlash sinc local develop basic understand pleas',
#  'ye sure wake much much earlier pictwittercompozlthhqe1',
#  ' narendramodi sir first time feel power vote ',
#  'peopl pleas dont add fuel fire say go away belliger natur help anyon use word wise help fellow stay calm dont know go wait announc',
# ...

# %%
#To create term dictionary, we must have eah string tokenised
tokenised_corpus=[]
for corp in corpus:
    
    tokenised_corpus.append([token for token in corp.split(" ")])
tokenised_corpus
# Out:
# [['basic',
#   'structur',
#   'motto',
#   'constitut',
#   'gonna',
#   'histor',
#   'misadventur',
#   ''],
#  ['phulwama',
#   'gafoor',
#   'said',
#   'talk',
#   'media',
#   'support',
#   'pak',
#   'armi',
#   'otherwis',
#   'could',
#   'defeat',
#   'india',
#   'guy',
#   'get',
#   'sm',
#   'gafoor',
#   'sab',
#   'zarrarkhuhro',
#   'start',
#   'sing',
#   'unison',
#   ''],
#  ['r',
#   'u',
#   'instig',
#   'peopl',
#   'stop',
#   'spread',
#   'venomlet',
#   'india',
#   'wit',
#   'histori',
#   'need',
#   'go'],
#  ['observ',
#   'govt',
#   'last',
#   '5',
#   'year',
#   'never',
#   'believ',
#   'might',
#   'scrape',
#   'recent',
#   'develop',
#   'assur',
#   'gimmick',
#   ''],
#  ['alway', 'good', 'thing', 'listen', 'peopl', 'know', ''],
#  ['time',
#   'abolish',
#   'apartheid',
#   'amalgam',
#   'kashmir',
#   'peopl',
#   'india',
#   'statu',
#   'quo',
#   'kashmir',
#   ''],
#  ['jai', 'hind', 'dosto', 'filthi', 'blood', 'terror', ''],
# ...

# %%
dictionary = corpora.Dictionary(tokenised_corpus) #storing the corpous word into dictionary

# %%
len(dictionary) # the length of the words
# Out:
# 60593

# %%
dictionary[0] #word '' has index 0
# Out:
# ''

# %%
doc_term_matrix = [dictionary.doc2bow(rev) for rev in tokenised_corpus]

# %%
doc_term_matrix[1]
# Out:
# [(0, 1),
#  (8, 1),
#  (9, 1),
#  (10, 1),
#  (11, 2),
#  (12, 1),
#  (13, 1),
#  (14, 1),
#  (15, 1),
#  (16, 1),
#  (17, 1),
#  (18, 1),
#  (19, 1),
#  (20, 1),
#  (21, 1),
#  (22, 1),
#  (23, 1),
#  (24, 1),
#  (25, 1),
#  (26, 1),
#  (27, 1)]

# %%
dictionary[40]
# Out:
# 'assur'

# %%
### Creating the object for LDA model using gensim library
LDA = gensim.models.ldamodel.LdaModel

# Build LDA model
lda_model = LDA(corpus=doc_term_matrix, id2word=dictionary, num_topics=21, random_state=100,
                chunksize=1000, passes=50)

# %%
lda_model.print_topics()
# Out:
# [(5,
#   '0.106*"support" + 0.094*"" + 0.085*"congress" + 0.053*"bjp" + 0.045*"parti" + 0.039*"tweet" + 0.034*"better" + 0.031*"pleas" + 0.031*"vote" + 0.026*"rahulgandhi"'),
#  (6,
#   '0.082*"" + 0.052*"minist" + 0.038*"use" + 0.033*"live" + 0.030*"pass" + 0.030*"bill" + 0.029*"home" + 0.029*"follow" + 0.029*"sabha" + 0.027*"revok"'),
#  (19,
#   '0.100*"modi" + 0.066*"said" + 0.053*"" + 0.045*"shah" + 0.043*"pm" + 0.034*"amit" + 0.033*"valley" + 0.032*"girl" + 0.029*"cant" + 0.027*"decid"'),
#  (12,
#   '0.056*"" + 0.050*"new" + 0.037*"histori" + 0.034*"made" + 0.033*"famili" + 0.032*"benefit" + 0.032*"make" + 0.032*"india" + 0.028*"creat" + 0.027*"that"'),
#  (2,
#   '0.072*"govern" + 0.068*"govt" + 0.065*"decis" + 0.061*"" + 0.037*"move" + 0.030*"modi" + 0.026*"india" + 0.024*"peopl" + 0.024*"indian" + 0.023*"n"'),
#  (13,
# ...

# %% [markdown]
# ### Visualise Topics

# %%
# libraries for visualization
import pyLDAvis
import pyLDAvis.gensim

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, doc_term_matrix, dictionary)
vis
# Out:
# /anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 13    -0.143951 -0.203924  1       1        7.030828
# 9     -0.151335  0.127556  2       1        6.497393
# 2     -0.116443 -0.076319  3       1        6.483639
# 17    -0.092674  0.061123  4       1        6.122002
# 10    -0.156663  0.141399  5       1        6.028751
# 14    -0.140402  0.104835  6       1        5.662016
# 1      0.093993  0.084724  7       1        5.456229
# 6     -0.037302  0.005059  8       1        5.443592
# 0      0.011480 -0.158854  9       1        5.258584
# 3     -0.067951 -0.211100  10      1        4.949465
# ...

# %%
lda_model[doc_term_matrix[1]] #Gets the topic distribution of first document
# Out:
# [(0, 0.11865282),
#  (5, 0.06128046),
#  (9, 0.13942854),
#  (10, 0.5784333),
#  (19, 0.05987368)]

# %% [markdown]
# -> i got 19 dominante topics from all the tweets

# %% [markdown]
# ### TOPIC 19  DOMINANTE

# %%
lda_model.show_topic(19) #  listing all the dominante words
# Out:
# [('modi', 0.100231536),
#  ('said', 0.06577615),
#  ('', 0.052796535),
#  ('shah', 0.04507737),
#  ('pm', 0.04299366),
#  ('amit', 0.034017287),
#  ('valley', 0.033127576),
#  ('girl', 0.031999078),
#  ('cant', 0.028584046),
#  ('decid', 0.026733125)]

# %% [markdown]
# ### This is a list of tuple, with word and its score. We can extract the topic words from here. Let us use this to get dominant topic is each TWEETS

# %%
def format_topics_sentences(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=doc_term_matrix, texts=corpus)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0  0            8.0             0.5415
# 1  1            10.0            0.5784
# 2  2            10.0            0.3305
# 3  3            16.0            0.6568
# 4  4            14.0            0.3793
# 5  5            13.0            0.5798
# 6  6            20.0            0.3861
# 7  7            2.0             0.5119
# 8  8            10.0            0.6246
# 9  9            16.0            0.4354
#
#                                                             Keywords  \
# 0  articl, 370, , address, still, abolish, scrap, 35a, remov, cannot
# 1  , know, peopl, dont, need, first, stop, think, talk, 2
# 2  , know, peopl, dont, need, first, stop, think, talk, 2
# 3  , well, way, done, last, good, go, work, much, time
# 4  , like, see, even, polit, world, show, watch, look, situat
# 5  kashmir, india, , pakistan, part, issu, say, abrog, peopl, trade
# 6  year, tell, alway, 70, believ, jai, war, wrong, hind, imran
# ...

# %%
lda_model.log_perplexity(doc_term_matrix) #Perplexoity, lower the better
# Out:
# -13.515222268566923

# %% [markdown]
# ->the lower the better is the perplexity score
